# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df =pd.read_csv("IMDB-Movie-Data.csv")
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
a=list(df["Title"])
a
# Out:
# ['Guardians of the Galaxy',
#  'Prometheus',
#  'Split',
#  'Sing',
#  'Suicide Squad',
#  'The Great Wall',
#  'La La Land',
#  'Mindhorn',
#  'The Lost City of Z',
#  'Passengers',
#  'Fantastic Beasts and Where to Find Them',
#  'Hidden Figures',
#  'Rogue One',
#  'Moana',
#  'Colossal',
#  'The Secret Life of Pets',
#  'Hacksaw Ridge',
#  'Jason Bourne',
#  'Lion',
#  'Arrival',
#  'Gold',
#  'Manchester by the Sea',
#  'Hounds of Love',
#  'Trolls',
#  'Independence Day: Resurgence',
#  'Paris pieds nus',
#  'Bahubali: The Beginning',
#  'Dead Awake',
#  'Bad Moms',
#  "Assassin's Creed",
#  'Why Him?',
#  'Nocturnal Animals',
#  'X-Men: Apocalypse',
#  'Deadpool',
#  'Resident Evil: The Final Chapter',
#  'Captain America: Civil War',
#  'Interstellar',
#  'Doctor Strange',
#  'The Magnificent Seven',
#  '5- 25- 77',
#  'Sausage Party',
#  'Moonlight',
#  "Don't Fuck in the Woods",
#  'The Founder',
#  'Lowriders',
#  'Pirates of the Caribbean: On Stranger Tides',
# ...

# %%
b=list(df["Year"])
b
# Out:
# [2014,
#  2012,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2015,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2014,
#  2016,
#  2016,
#  2007,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2011,
#  2016,
#  2016,
#  2016,
#  2016,
#  2015,
#  2016,
#  2016,
#  2014,
#  2008,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2015,
#  2006,
#  2014,
#  2016,
#  2015,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2007,
#  2012,
#  2009,
#  2006,
#  2016,
#  2010,
#  2016,
#  2013,
#  2014,
#  2015,
#  2015,
#  2016,
#  2009,
#  2015,
#  2016,
#  2013,
#  2016,
#  2011,
#  2016,
#  2015,
#  2016,
#  2016,
#  2016,
#  2016,
#  2006,
#  2015,
#  2011,
#  2015,
#  2016,
#  2015,
#  2016,
#  2016,
#  2016,
#  2016,
#  2014,
#  2016,
# ...

# %%
# how much revenue did the movies generate 

df[['Title','Revenue (Millions)']].value_counts()
# Out:
# Title                    Revenue (Millions)
# (500) Days of Summer     32.39                 1
# Step Up                  65.27                 1
# Split                    138.12                1
# Spotlight                44.99                 1
# Spring Breakers          14.12                 1
#                                               ..
# Immortals                83.50                 1
# In Bruges                7.76                  1
# In Time                  37.55                 1
# In the Heart of the Sea  24.99                 1
# Zootopia                 341.26                1
# Length: 872, dtype: int64

# %%
df['Runtime (Minutes)']
a = list(df['Runtime (Minutes)'])
plt.hist(a)
# Out:
# (array([  3.,  78., 256., 268., 208.,  98.,  52.,  26.,   6.,   5.]),
#  array([ 66. ,  78.5,  91. , 103.5, 116. , 128.5, 141. , 153.5, 166. ,
#         178.5, 191. ]),
#  <BarContainer object of 10 artists>)

# %%
# best movie based on rating, votes and revenue
df[['Title','Revenue (Millions)','Votes','Year']]
# Out:
#                        Title  Revenue (Millions)   Votes  Year
# 0    Guardians of the Galaxy              333.13  757074  2014
# 1                 Prometheus              126.46  485820  2012
# 2                      Split              138.12  157606  2016
# 3                       Sing              270.32   60545  2016
# 4              Suicide Squad              325.02  393727  2016
# ..                       ...                 ...     ...   ...
# 995     Secret in Their Eyes                 NaN   27585  2015
# 996          Hostel: Part II               17.54   73152  2007
# 997   Step Up 2: The Streets               58.01   70699  2008
# 998             Search Party                 NaN    4881  2014
# 999               Nine Lives               19.64   12435  2016
#
# [1000 rows x 4 columns]

# %%
df1=df[['Votes','Rating','Revenue (Millions)','Title']].max
df1
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of       Votes  Rating  Revenue (Millions)                    Title
# 0    757074     8.1              333.13  Guardians of the Galaxy
# 1    485820     7.0              126.46               Prometheus
# 2    157606     7.3              138.12                    Split
# 3     60545     7.2              270.32                     Sing
# 4    393727     6.2              325.02            Suicide Squad
# ..      ...     ...                 ...                      ...
# 995   27585     6.2                 NaN     Secret in Their Eyes
# 996   73152     5.5               17.54          Hostel: Part II
# 997   70699     6.2               58.01   Step Up 2: The Streets
# 998    4881     5.6                 NaN             Search Party
# 999   12435     5.3               19.64               Nine Lives
#
# [1000 rows x 4 columns]>

# %%
plt.hist(df['Votes'])
# Out:
# (array([649., 225.,  80.,  29.,   7.,   7.,   1.,   0.,   1.,   1.]),
#  array([6.1000000e+01, 1.7924650e+05, 3.5843200e+05, 5.3761750e+05,
#         7.1680300e+05, 8.9598850e+05, 1.0751740e+06, 1.2543595e+06,
#         1.4335450e+06, 1.6127305e+06, 1.7919160e+06]),
#  <BarContainer object of 10 artists>)
