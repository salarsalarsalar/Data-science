# %%
import pandas as pd
import numpy as np
directory_to_extract_to="C:/Users/Ahsan Makhdoom/Downloads"
import zipfile
with zipfile.ZipFile("C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1.zip", 'r') as zip_ref:
    zip_ref.extractall(directory_to_extract_to)

# %%
import os,zipfile
from pydub import AudioSegment
fn=[]
dir_name = 'C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1'
extension = ".zip"
os.chdir(dir_name) # change directory from working dir to dir with files
for names in os.listdir(dir_name):
    name, ext = os.path.splitext(names)
    if ext == ".zip":
        with zipfile.ZipFile(names, 'r') as zip:
            zip.extractall()
            with zipfile.ZipFile(names, 'r') as zip:
                fn=zip.namelist()
    os.remove(names)
    for file in fn:
    #spliting the file into the name and the extension
        name, ext = os.path.splitext(file)
        
#         if ext == ".mp3":
        src="C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1/"+str(file)
        try:
            mp3_sound = AudioSegment.from_file(src)
            mp3_sound.export("{0}.wav".format(name), format="wav")
            os.remove(src)
        except:
            pass

# %%
import os, zipfile
import shutil
import os

dir_name = 'C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1'
for i in os.listdir(dir_name):
    src = "C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1/" + str(i) + "/"
    try:
        name=i.replace("-", "")
        os.rename(src, str(dir_name)+"/"+str(name.upper()))
    except:
        pass
for i in os.listdir(dir_name):
    for j in os.listdir('C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1/' + str(i)):
        new_name = j.replace("_TV", "T.V",)
        try:
            src = "C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1/" + str(i) + "/"
            os.rename(src+ str(j), src+new_name.upper())
        except:
            pass
arr=[]

for j in os.listdir('C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1/I200613'):
    arr.append(j)

# %%
import os, zipfile

dir_name = 'C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1'
for i in os.listdir(dir_name):
    for j in os.listdir('C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1/' + str(i)):
        new_name = j.replace("RUHA", "")
        try:
            src = "C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1/" + str(i) + "/"
            os.rename(src+ str(j), src+i+"_"+new_name)
        except:
            pass

# %%
import shutil
import os

name='C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1/I200626'
arr=[]
for i in os.listdir(name):
    arr.append(i[8:])



src = "C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1"
dst = "C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1"
for lst in os.listdir(src):
    counter = 0
    src = "C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1"
    src = src + "/" + str(lst)
    for item in os.listdir(src):
        dst = "C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1"
        s=str(src)+"/"+str(item)
        try:
            counter = arr.index(item[8:])
        except:
            print(item)
            pass
        dst = str(dst) + "/" + "class_" + str(counter)
        d = dst
        if not os.path.exists(dst):
            os.makedirs(dst)
        if os.path.isdir(src):
            shutil.copy2(s, d)
        else:
            if not os.path.exists(d) or os.stat(src).st_mtime - os.stat(d).st_mtime > 1:
                shutil.copy2(s, d)
        counter += 1

# %%
dir_name = 'C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1'
for i in os.listdir(dir_name):
    if len(os.listdir("C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1/" + str(i))) <=0: # Check if the folder is empty
        shutil.rmtree("C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1/" + str(i))

import os
dir_name = 'C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1'
for i in os.listdir(dir_name):
    new_name='C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1/' + str(i)
    for j in os.listdir(new_name):
        src=new_name+"/"+str(j)
        name, ext = os.path.splitext(src)
        if ext!=".WAV":
            print(src)
            os.remove(src)

# %%
import os, zipfile
import pandas as pd
import numpy as np

data = pd.DataFrame()
dir_name = 'C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1'
for i in os.listdir(dir_name):
    for j in os.listdir('C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1/' + str(i)):
        data = data.append({'Name': j,'Class': i}, ignore_index=True)

data
# Out:
#          Class                                  Name
# 0      class_0           19I1664_A.C AHISTA KARO.WAV
# 1      class_0           19I1696_A.C AHISTA KARO.WAV
# 2      class_0           I191714_A.C AHISTA KARO.WAV
# 3      class_0           I191716_A.C AHISTA KARO.WAV
# 4      class_0           I191763_A.C AHISTA KARO.WAV
# ...        ...                                   ...
# 2696  class_99   I202651_WASHROOM KA BULB ON KRO.WAV
# 2697  class_99  I202653_WASHROOM KA BULB ON KARO.WAV
# 2698  class_99  I202654_WASHROOM KA BULB ON KARO.WAV
# 2699  class_99  I202656_WASHROOM KA BULB ON KARO.WAV
# 2700  class_99  I202658_WASHROOM KA BULB ON KARO.WAV
#
# [2701 rows x 2 columns]

# %%
import librosa
y, sr = librosa.load('C:/Users/Ahsan Makhdoom/Downloads/Assignment 7 part 1/class_0/19I1664_A.C AHISTA KARO.WAV')
onset_env = librosa.onset.onset_strength(y, sr=sr)
tempo = librosa.beat.tempo(onset_envelope=onset_env, sr=sr)
