# %% [markdown]
# # Name:
# # Roll No.:
# # Assignment 6

# %% [markdown]
# # Instruction

# %% [markdown]
# 1. Don’t plagiarize, Plagiarism would lead to straight zero
# 2. Clearly mention your NAME and ROLL NO#.
# 3. Late submissions are not allowed. Start Early.

# %%
#import libraries
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.edge.options import Options
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
import re
from lxml import html

# %% [markdown]
# # Question 1

# %% [markdown]
# Scrape 2 pages of the reviews for a single product listing using product URL.<br /> Note: Product must have more than 1 review page. The code must be generic and should work for every product listing URL, with proper checks in place.

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from lxml import html
from selenium.webdriver.chrome.options import Options
import pandas as pd
import time
options = Options()
driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
Data = pd.DataFrame([],columns=['Name', 'Reviews'])
url='https://www.daraz.pk/products/metro-70cc-motorcycle-mr70-tez-raftar-red-black-motorbike-lahore-gujranwala-sialkot-islamabad-karachi-faisalabad-only-i134510726-s1294898802.html?spm=a2a0e.searchlist.list.1.39e6276a19MyPa&search=1'
driver.get(url)
count=1
for j in range(5):
    names = [x.text[3:] for x in driver.find_elements_by_xpath("//*[@class='item']/div[@class='middle']/span[1]")]
    ##print(names)
    product_reviews = [x.text.replace('\n','') for x in driver.find_elements_by_xpath("//*[@class='item']/div[@class='item-content']/div[@class='content']")]
    ##print(product_reviews)
    for i in range(5):
        Data.loc[count-1] = [names[i],product_reviews[i]]
        count+=1
    
    try:
        click_next = driver.find_element_by_css_selector('button.next-btn.next-btn-normal.next-btn-medium.next-pagination-item.next')
        driver.execute_script("arguments[0].click();", click_next)
        time.sleep(4)
    except:
        break
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [C:\Users\Minahil Ashfaq\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache
# <ipython-input-2-c3a58a5f57f0>:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
# <ipython-input-2-c3a58a5f57f0>:14: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   names = [x.text[3:] for x in driver.find_elements_by_xpath("//*[@class='item']/div[@class='middle']/span[1]")]
# <ipython-input-2-c3a58a5f57f0>:16: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   product_reviews = [x.text.replace('\n','') for x in driver.find_elements_by_xpath("//*[@class='item']/div[@class='item-content']/div[@class='content']")]
# <ipython-input-2-c3a58a5f57f0>:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   click_next = driver.find_element_by_css_selector('button.next-btn.next-btn-normal.next-btn-medium.next-pagination-item.next')

# %%
#Output
Data
# Out:
#                  Name                                            Reviews
# 0          Shabbir A.  with the positive approach of management of Me...
# 1               W***.  Very good motorcycle. Great experience of buyi...
# 2   sohailnazir607607  Bike condition was 100% okay. Delivery was goo...
# 3            Bilal S.  I think Metro company is giving us a chance to...
# 4           Farooq A.  Product quality is Good. Before time delivery....
# 5               W***.  دراز سے میٹرو موٹرسائیکل کا یہ سپیشل ماڈل خرید...
# 6               a***.  Dam Hai bike mein Metro motorcycle ki kya baat...
# 7               a***.  My new metro bike, i have purchased from daraz...
# 8            adnan B.  I like metro motorcycle beacuse i have already...
# 9            Imran S.  Satisfied from seller, Next day he deliver ho ...
# 10              3***5  I proud to have this bike.Thanks metro Thanks ...
# 11              3***6                    engine sound is good. surprised
# 12              3***6                       rush deliveryquality product
# 13              3***6                          Thanks Daraz Thanks metro
# 14            Mian S.  Thx metro and draz for providing good service ...
# 15            afaq A.                              good dilevery on time
# 16              3***6                                   dilevery on time
# 17              3***6                                   dilevery on time
# 18            afaq A.                                      Good service
# 19           Hamza S.  i  am 100% satisfied with my metro motorcycle ...
# 20           Abdul M.                 Quality product, reasonable price
# 21               azar                               excellence Services
# 22            Mian S.  Very good service and very nice bike thanks me...
# 23           Imran A.  experience was good to purchase high rating br...
# 24         Murtaza M.  Mashallah! Delivered in 10/10 condition. Much ...

# %% [markdown]
# # Question 2

# %% [markdown]
# Scrape 80 items for a keyword search e.g., 'mobile covers'<br/>Note: Must use "click()" function of webElement, URL changing for pages is not allowed. The code must be generic and should work for every keyword, with proper checks in place. Bonus for also scraping country and Daraz Mall availability.

# %%
#Output
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.edge.options import Options
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
import re
from lxml import html

product = input('Enter Product Name : ').replace(" ","+")
daraz = 'https://www.daraz.pk/catalog/?q={}'.format(product)
print('URL : ',daraz,'\n')

pages = int(input('Enter no. of Pages you Want: '))

Web_Data = pd.DataFrame([],columns=['Name', 'Daraz Mall?', 'Original Price','Discounted Price', 'Rating' ,'Reviews', 'Seller Country'])
value = {'c3dn4k c1dtTC' : 0,'c3dn4k c1Zozd' : 0.1,'c3dn4k cbDGcO' : 0.2,'c3dn4k c3fsPU' : 0.3,'c3dn4k c1e2gb' : 0.4,'c3dn4k c3An30' : 0.5,'c3dn4k c3DcGB' : 0.6,'c3dn4k c1wCjy' : 0.7,'c3dn4k c17YMy' : 0.8,'c3dn4k cF1vkb' : 0.9,'c3dn4k c3EEAg' : 1}
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(daraz)
index = 0
for i in range(7):
    for product in driver.find_elements_by_class_name('c2prKC'):
        
        print('*', end = '')
        name = product.find_element_by_class_name('c16H9d').text
        prize = int(product.find_element_by_class_name('c3gUW0').text[3:].replace(',',''))
        country = product.find_element_by_class_name('c2i43-').text

        rating = 0
        try:
            stars = product.find_element_by_class_name('c15YQ9').get_attribute('innerHTML')
            for s in re.findall('(c3dn4k c.+?)"', stars):
                rating +=value[s]
        except NoSuchElementException:
            rating = 0

        daraz_mall = 0
        mall = product.find_element_by_class_name('c3vCyH').get_attribute('innerHTML')
        if len(mall)>0:
            daraz_mall = 'Yes'
        else:
            daraz_mall = 'No'

        reviews = 0
        try:
            reviews = int(product.find_element_by_class_name('c3XbGJ').text[1:-1])
        except NoSuchElementException:
            reviews = 0

        discount_prize = 0
        try:
            discount_prize = int(product.find_element_by_class_name('c1-B2V').text[3:].replace(',',''))
        except NoSuchElementException:
            discount_prize = 0

        if discount_prize==0:
            Web_Data.loc[index] = [name, daraz_mall, prize, discount_prize, rating, reviews, country]
        else:
            Web_Data.loc[index] = [name, daraz_mall, discount_prize, prize, rating, reviews, country]
        index += 1
        
    try:
        click_next = driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[3]/div/ul/li[9]/a')
        driver.execute_script("arguments[0].click();", click_next)
        time.sleep(5)
    except:
        print("....")

Web_Data
# Out:
# Enter Product Name :  motorcycle
# URL :  https://www.daraz.pk/catalog/?q=motorcycle
# Enter no. of Pages you Want:  3
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [C:\Users\Minahil Ashfaq\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache
# <ipython-input-4-3ac242662409>:22: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# <ipython-input-4-3ac242662409>:26: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for product in driver.find_elements_by_class_name('c2prKC'):
# ****************************************
# <ipython-input-4-3ac242662409>:67: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   click_next = driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[3]/div/ul/li[9]/a')
# ************************************************************************************************************************************************************************************************************************************************
#                                                   Name Daraz Mall?  \
# 0    METRO 70cc Motorcycle - MR70 (Tez Raftar) Blac...         Yes
# 1         METRO 100cc Motorcycle - MR100 Red Motorbike         Yes
# 2    METRO 70cc Motorcycle - MR70 Red Motorbike (La...         Yes
# 3    METRO 125cc Motorcycle - MR125 Red Motorbike (...         Yes
# 4    METRO 70cc Motorcycle - MR70 (Self Start) Red ...         Yes
# ..                                                 ...         ...
# 275  Motorcycle Bike Universal Waterproof Dustproof...          No
# 276  Mud flap Motorcycle Fender Extender Splash Whe...          No
# 277  10 Pcs/Pack Retro Style Graffiti Travel Funny ...          No
# 278  Fleece Air-soft Bike Half Face Cover Hood Prot...          No
# 279  Photo Transparent Crystal Smile Key Chains Smi...          No
#
#     Original Price Discounted Price Rating Reviews Seller Country
# 0            59999                0      5     115       Pakistan
# 1            68499                0    4.9     150       Pakistan
# 2            63500                0      5     363       Pakistan
# 3            95499                0    4.9      73       Pakistan
# 4            74500                0    4.8      23       Pakistan
# ..             ...              ...    ...     ...            ...
# 275            650              337    4.7      35       Pakistan
# 276            350              250    4.8      81       Pakistan
# 277            300              163    4.6      80       Pakistan
# 278            350              195    4.8      56       Pakistan
# 279             49               35    4.5     181       Pakistan
#
# [280 rows x 7 columns]

# %% [markdown]
# # Question 3

# %% [markdown]
# Which Products are on Flash sale? Display Product name, Actual Price, Discounted Price, Discount Percentage, Rating, No. of Reviews, Top 3 reviews displayed.
#
# Display output must be like this. Products may vary.

# %%
#Run this cell to see output
pd.read_csv('sample.csv')

# %% [markdown]
# # Question 4

# %% [markdown]
# #### Submit .py file

# %%
Web_Data
# Out:
#                                                   Name Daraz Mall?  \
# 0    Code Checkered Buttoned Down Casual Shirt for ...         Yes
# 1    Code Denim Double Pocket Buttoned Down Casual ...         Yes
# 2    Polo Shirt for Men's High Quality Short sleeve...          No
# 3    Dot Printed Office Wear Gents Dress Semi Forma...          No
# 4    Office Wear Gents Check Dress Formal Shirt For...          No
# ..                                                 ...         ...
# 275  men's essential, Polo T-shirt, Smart fit, Cott...          No
# 276  Ababil Yellow/Blue Multi-Striped Men's Casual ...         Yes
# 277               Different Color Polo T Shirt for men          No
# 278  Shahzeb Saeed Black & Yellow Check Casual Shir...         Yes
# 279    Anace Burgundy 100% Cotton Polo Shirt for Men's         Yes
#
#     Original Price Discounted Price Rating Reviews Seller Country
# 0             1750              948      5      20       Pakistan
# 1             1750              930    4.7      59       Pakistan
# 2             1499              742    4.7     154       Pakistan
# 3             1320              539    4.3     166       Pakistan
# 4             1320              649    4.4     115       Pakistan
# ..             ...              ...    ...     ...            ...
# 275            600              550      5       1       Pakistan
# 276           2799             1614    3.5       2       Pakistan
# 277            650              450    4.9      22       Pakistan
# 278           2950              990      5       2       Pakistan
# 279           1600              742      5       9       Pakistan
#
# [280 rows x 7 columns]

# %%
value = {'c3dn4k c1dtTC' : 0,'c3dn4k c1Zozd' : 0.1,'c3dn4k cbDGcO' : 0.2,'c3dn4k c3fsPU' : 0.3,'c3dn4k c1e2gb' : 0.4,'c3dn4k c3An30' : 0.5,'c3dn4k c3DcGB' : 0.6,'c3dn4k c1wCjy' : 0.7,'c3dn4k c17YMy' : 0.8,'c3dn4k cF1vkb' : 0.9,'c3dn4k c3EEAg' : 1}
daraz = 'https://www.daraz.pk/wow/i/pk/landingpage/flash-sale?spm=a2a0e.home.flashSale.1.f3e54937mncMpX&wh_weex=true&amp;wx_navbar_transparent=true&amp;scm=1003.4.icms-zebra-5029921-2824236.OTHER_5360388823_2475751&skuIds=237325209,217575214,133734313,227580069,220398509,112728024,188478877'
driver = webdriver.Chrome(ChromeDriverManager().install())
wait = WebDriverWait(driver, 10)
driver.get(daraz)
index = 0
name=[]
for i in range(1):
    try:
        click_next = driver.find_element_by_xpath("//*[@id='campaign-1637002800000']/div/a["+str(i+1)+"]/div")
        driver.execute_script("arguments[0].click();", click_next)
        time.sleep(5)
    except:
        break
    
    price = 0
    try:
        price =int(driver.find_element_by_xpath('//*[@id="module_product_price_1"]/div/div/div/span[1]').text[3:].replace(',',''))
    except NoSuchElementException:
        price = 0
    reviews = 0
    try:
        reviews =driver.find_element_by_xpath('//*[@id="module_product_review_star_1"]/div/a[1]').text[1:-1]
    except NoSuchElementException:
        reviews = 0
    discount_prize = 0
    try:
        discount_prize = int(driver.find_element_by_xpath('//*[@id="module_product_price_1"]/div/div/span').text[3:].replace(',',''))
    except NoSuchElementException:
        discount_prize = 0
    rating = 0
    try:
        rating =driver.find_element_by_xpath('//*[@class="score-average"]')
    except NoSuchElementException:
        rating = 0
    discount = 0
    try:
        discount = driver.find_element_by_xpath('//*[@id="module_product_price_1"]/div/div/div/span[2]')
    except NoSuchElementException:
        discount = 0
    
        
    

# name= [x.text for x in driver.find_elements_by_xpath("//*[@class='sale-title']")]
# price= [x.text[3:].replace(',','') for x in driver.find_elements_by_xpath("//*[@class='sale-price']")]
# try:
#     stars = driver.find_element_by_class_name('c15YQ9').get_attribute('innerHTML')
#     for s in re.findall('(c3dn4k c.+?)"', stars):
#         rating +=value[s]
# except NoSuchElementException:
#     rating = 0



driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST chromedriver version for 95.0.4638 google-chrome
# Driver [C:\Users\Ahsan Makhdoom\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# <ipython-input-54-6d9a5a281c24>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# <ipython-input-54-6d9a5a281c24>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   click_next = driver.find_element_by_xpath("//*[@id='campaign-1637002800000']/div/a["+str(i+1)+"]/div")
# <ipython-input-54-6d9a5a281c24>:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   price =int(driver.find_element_by_xpath('//*[@id="module_product_price_1"]/div/div/div/span[1]').text[3:].replace(',',''))
# <ipython-input-54-6d9a5a281c24>:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   reviews =driver.find_element_by_xpath('//*[@id="module_product_review_star_1"]/div/a[1]').text[1:-1]
# <ipython-input-54-6d9a5a281c24>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   discount_prize = int(driver.find_element_by_xpath('//*[@id="module_product_price_1"]/div/div/span').text[3:].replace(',',''))
# <ipython-input-54-6d9a5a281c24>:33: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   rating =driver.find_element_by_xpath('//*[@class="score-average"]')
# <ipython-input-54-6d9a5a281c24>:38: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   discount = driver.find_element_by_xpath('//*[@id="module_product_price_1"]/div/div/div/span[2]')

# %%
discount
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="83a35a132e0c61a438e64fbd084f3348", element="ffc799cc-0890-471b-9110-b9f57b8fea3e")>

# %%
Data = pd.DataFrame([],columns=['Name', 'Actual_Price', 'Discounted_Price','Discount', 'Rating' ,'Reviews','Review1','Review2','Review3'])
daraz = 'https://www.daraz.pk/wow/i/pk/landingpage/flash-sale?spm=a2a0e.home.flashSale.1.35e34937iU3BAy&wh_weex=true&amp;wx_navbar_transparent=true&amp;scm=1003.4.icms-zebra-5029921-2824236.OTHER_5360388823_2475751&skuIds=3849186,222241404,4157310,115618473,144108408,131136978,3849189'
options = Options()
driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
index = 1
i=0
while(True):
    i+=1
    driver.get(daraz)

    try:
        click_next = driver.find_element_by_xpath("//*[@id='campaign-1637089200000']/div/a["+str(i)+"]/div")
        driver.execute_script("arguments[0].click();", click_next)
        time.sleep(15)
    except:
        break
    name = driver.find_element_by_xpath("//*[@id='module_product_title_1']/div/div/span").text.replace('\n','')
    discount = 0
    try:
        discount =int( driver.find_element_by_xpath('//*[@id="module_product_price_1"]/div/div/div/span[2]').text[1:-1])
    except NoSuchElementException:
        discount = 0
    price = 0
    try:
        price =int(driver.find_element_by_xpath('//*[@id="module_product_price_1"]/div/div/div/span[1]').text[4:].replace(',',''))
    except NoSuchElementException:
        price=0
    rating = 0
    try:
        rating =float(driver.find_element_by_class_name('score-average').text)
    except NoSuchElementException:
        rating = 0
    discount_prize = 0
    try:
        discount_prize = int(driver.find_element_by_xpath('//*[@id="module_product_price_1"]/div/div/span').text[3:].replace(',',''))
    except NoSuchElementException:
        discount_prize = 0
    reviews = 0
    try:
        reviews =driver.find_element_by_xpath('//*[@id="module_product_review_star_1"]/div/a[1]').text[:-8]
    except NoSuchElementException:
        reviews = 0
    review1 =""
    try:
        review1 =driver.find_element_by_xpath('//*[@id="module_product_review"]/div/div[3]/div[1]/div[1]/div[3]/div[1]').text.replace('\n','')
    except NoSuchElementException:
        review1 = "No comments"
    try:
        review2 =driver.find_element_by_xpath('//*[@id="module_product_review"]/div/div[3]/div[1]/div[2]/div[3]/div[1]').text.replace('\n','')
    except NoSuchElementException:
        review2 = "No comments"
    try:
        review3 =driver.find_element_by_xpath('//*[@id="module_product_review"]/div/div[3]/div[1]/div[3]/div[3]/div[1]').text.replace('\n','')
    except NoSuchElementException:
        review3 = "No comments"
    Data.loc[index] = [name, price, discount_prize,discount, rating, reviews,review1,review2,review3]
    index += 1
    def export_csv(Data):
        df = pd.DataFrame(Data)
        df.to_csv("C:/Users/Ahsan Makhdoom/Downloads/books_exported.csv", index=False)
